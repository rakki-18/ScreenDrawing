# %%
import cv2

# %%
import mediapipe as mp
import numpy as np

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
hands = mp_hands.Hands(max_num_hands = 1, static_image_mode = True,min_detection_confidence = 0.5)

# %%
# storing all the coordinates at different timesteps in a list
list_x = []
list_y = []
list_z = []

# %%
# color and thickness of the lines
color = (255,0,0)
thickness = 2
# threshold after which we should start drawing
threshold = 10

# %%
# canvas on which we are drawing
canvas = np.zeros([512,512,1],dtype=np.uint8)

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, image = cap.read()
    
        
    if not success:
        print("video capture unsuccessful")
        break
    
    image = cv2.cvtColor(cv2.flip(image,1), cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = hands.process(image)
    
    
    
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        
        
        count2 = 0
        
        hand_landmarks = results.multi_hand_landmarks[0]
        for keypoint_landmark in results.multi_hand_landmarks[0].landmark:
            # if keypoint is that of the tip of the index finger
            if(count2 == 8):
                
                if(len(list_x) > threshold):
                    # get the current coordinates as endpoint
                    end_point = (int(keypoint_landmark.x*256), int(keypoint_landmark.y*256))
                    # get the previous coordinates as the start point
                    start_point = (list_x[-1], list_y[-1])
                    # draw a line joining these points
                    cv2.line(canvas,start_point, end_point,color, thickness)
                # add the coordinates to the list
                list_x.append(int(keypoint_landmark.x*256))
                list_y.append(int(keypoint_landmark.y*256))
                list_z.append(int(keypoint_landmark.z*256))
                
            
            count2 = count2+1
            
        mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        
        
    # show the canvas and the webcam image   
    cv2.imshow("Detected Hands", image)
    cv2.imshow("Result", canvas) 
    
    # exit when the user presses 's'
    if cv2.waitKey(5) & 0xFF == ord('s'):
        break
hands.close()
cap.release()

# %%
print(list_z)
# Out:
# [-41, -80, -41, -44, -77, -57, -59, -98, 47, -64, -97, -72, -24, -36, -62, -52, -46, -22, -17, -17, -23, -21, -23, -21, -20, -18, -19, -17, -17, -14, -14, -10, -12, -15, -13, -12, -21, -18, -18, -14, -15, -13, -18, -13, -15, -14, -22, -15, -14, -14, -12, -17, -16, -12, -14, -23, -19, -19, -19, -19, -25, -28, -29, -25, -35, -28, -25, -41, -33, -25, -29, -21, -26, -23, -24, -18, -13, -28, -50, -19, -18, -27, -28, -27, -24, -26, -26, -52, -25, -31, -39, -33, -28, -27, -22, -22, -23, -27, -21, -21, -19, -15, -20, -40, -23, -25, -22, -26, -24, -26, -19, -28, -33, -25, -26, -29, -21, -16, -34, -18, -32, -27, -24, -48, -46, -31, -19, -53, -24, -29, -55, -46, -61, -35, -21, -19, -36, -31, -28, -29, -22, -50, -30, -31, -36, -35, -51, -41, -47, -56, -41, -41, -43, -54, -46, -26, -34, -15, -41, -31, -22, -45, -30, -42, -44, -32, -39, -50, -26, -41, -67, -32, -24, -23, -30, -25, -56, -30, -43, -37, -16, -37, -24, -26, -31, -23, -31, -21, -50, -31, -37, -37, -22, -27, -22, -55, -25, -26, -22, -41, -23, -27, -35, -45, -32, -27, -44, -56, -57, -54, -45, -42, -53, -44, -39, -27, -47, -46, -46, -25, -41, -52, -61, -41, -36, -32, -47, -56, -58, -42, -32, -32, -35, -41, -31, -54, -37, -28, -38, -30, -29, -40, -24, -21, -37, -51, -18, -20, -15, -14, -25, -19, -29, -16, -31, -32, -26, -30, -14,